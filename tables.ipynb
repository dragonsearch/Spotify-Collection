# %%
import great_tables as gt
import numpy as np
import pandas as pd

# %%
# Import data
artists = pd.read_csv('data/spotify_artists_¬.csv', sep='¬')
# Out:
# /tmp/ipykernel_140902/1678315139.py:2: ParserWarning: Falling back to the 'python' engine because the separator encoded in utf-8 is > 1 char long, and the 'c' engine does not support such separators; you can avoid this warning by specifying engine='python'.
#   artists = pd.read_csv('data/spotify_artists_¬.csv', sep='¬')

# %%
# Get 3 rows

# %%
# Create a table
def table(df):
    
        return gt.GT(df).tab_options(
            container_width = "100%",
            table_background_color="lightblue",
            heading_background_color = "gold",
            column_labels_background_color="aquamarine",
            row_group_background_color="lightyellow",
            stub_background_color="lightgreen",
            source_notes_background_color="#f1e2af",
        )

table(artists.head(3))
# Out:
# GT(_tbl_data=                 track_id             track_artists        track_artist_ids
# 0  7lmeHLHBe4nmXzuXc0HDjk  Rage Against The Machine  2d0hyoQ5ynDBnkvAbJKORj
# 1  1wsRitfRRtWyEapl0q22o8  Rage Against The Machine  2d0hyoQ5ynDBnkvAbJKORj
# ...

# %%
# Load the data
millsong = pd.read_csv('data/spotify_millsongdata_%.csv', sep='%')
# Drop the first column
millsong = millsong.drop(columns=['Unnamed: 0'])

# %%
table(millsong.head(3))
# Out:
# GT(_tbl_data=  track_artist             track_name  \
# 0         ABBA  Ahe's My Kind Of Girl
# 1         ABBA       Andante, Andante
# 2         ABBA         As Good As New
#
#                                          link  \
# 0  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1       /a/abba/andante+andante_20002708.html
# 2        /a/abba/as+good+as+new_20003033.html
#
#                                               lyrics
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# ...

# %%
#load data
tracks = pd.read_csv('data/tracks_features_¬.csv', sep='¬')
# Out:
# /tmp/ipykernel_140902/694224983.py:2: ParserWarning: Falling back to the 'python' engine because the separator encoded in utf-8 is > 1 char long, and the 'c' engine does not support such separators; you can avoid this warning by specifying engine='python'.
#   tracks = pd.read_csv('data/tracks_features_¬.csv', sep='¬')

# %%
table(tracks.head(3))
# Out:
# GT(_tbl_data=                 track_id        track_name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk           Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8   Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7  Calm Like a Bomb  The Battle Of Los Angeles
#
#                  album_id  track_number  disc_number  explicit  danceability  \
# 0  2eia0myWFgoHuttJytCxgX             1            1     False         0.470
# 1  2eia0myWFgoHuttJytCxgX             2            1      True         0.599
# 2  2eia0myWFgoHuttJytCxgX             3            1     False         0.315
#
#    energy  key  ...  speechiness  acousticness  instrumentalness  liveness  \
# 0   0.978    7  ...       0.0727        0.0261          0.000011     0.356
# 1   0.957   11  ...       0.1880        0.0129          0.000071     0.155
# 2   0.970    7  ...       0.4830        0.0234          0.000002     0.122
#
# ...
